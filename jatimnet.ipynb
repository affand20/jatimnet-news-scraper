# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df = pd.read_csv('./outputs/jatimnet-news.csv')
df.head()
# Out:
#       id                                     url  \
# 0  27701  https://api.jatimnet.com/jinetapi/news
# 1  27700  https://api.jatimnet.com/jinetapi/news
# 2  27699  https://api.jatimnet.com/jinetapi/news
# 3  27698  https://api.jatimnet.com/jinetapi/news
# 4  27697  https://api.jatimnet.com/jinetapi/news
#
#                                                 slug category  \
# 0  berhasil-jadikan-status-kuning-kerja-keras-rel...   BERITA
# 1  polres-gresik-gelar-vaksinasi-dengan-sasaran-p...   DAERAH
# 2  khofifah-minta-perusahaan-di-jatim-manfaatkan-...   DAERAH
# 3  ppkm-turun-level-45-sekolah-di-madiun-mulai-ta...   DAERAH
# 4  pasca-ott-jual-beli-jabatan-pj-kades-mui-probo...   DAERAH
#
#                    published  \
# 0  2021-09-03T23:00:00+00:00
# 1  2021-09-03T11:00:00+00:00
# 2  2021-09-03T10:20:00+00:00
# 3  2021-09-03T09:40:00+00:00
# 4  2021-09-03T09:00:00+00:00
#
#                                             keywords  \
# ...
